# %% [markdown]
# # 1: IMPORT LIBRARIES AND DATASET

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# read the csv file 
admission_df = pd.read_csv('Admission_predict.csv')

# %%
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
admission_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
# Let's drop the serial no.
admission_df.drop('Serial No.', axis =1, inplace =True)
admission_df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# ..               ...
# 495             0.87
# 496             0.96
# 497             0.93
# 498             0.73
# 499             0.84
#
# [500 rows x 8 columns]

# %% [markdown]
# # 2: PERFORM EXPLORATORY DATA ANALYSIS

# %%
# checking the null values
admission_df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Check the dataframe information
admission_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# Statistical summary of the dataframe
admission_df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# 50%      8.560000    1.000000          0.72000
# 75%      9.040000    1.000000          0.82000
# max      9.920000    1.000000          0.97000

# %%
# Grouping by University ranking 
df_university = admission_df.groupby(by = 'University Rating').mean()
df_university
# Out:
#                     GRE Score  TOEFL Score       SOP      LOR       CGPA  \
# University Rating
# 1                  304.911765   100.205882  1.941176  2.426471  7.798529
# 2                  309.134921   103.444444  2.682540  2.956349  8.177778
# 3                  315.030864   106.314815  3.308642  3.401235  8.500123
# 4                  323.304762   110.961905  4.000000  3.947619  8.936667
# 5                  327.890411   113.438356  4.479452  4.404110  9.278082
#
#                    Research  Chance of Admit
# University Rating
# 1                  0.294118         0.562059
# 2                  0.293651         0.626111
# 3                  0.537037         0.702901
# 4                  0.780952         0.801619
# 5                  0.876712         0.888082

# %% [markdown]
# ### 3: PERFORM DATA VISUALIZATION

# %%
#Histogram

admission_df.hist(bins =30, figsize = (20, 20), color = 'b')
# Out:
# array([[<AxesSubplot:title={'center':'GRE Score'}>,
#         <AxesSubplot:title={'center':'TOEFL Score'}>,
#         <AxesSubplot:title={'center':'University Rating'}>],
#        [<AxesSubplot:title={'center':'SOP'}>,
#         <AxesSubplot:title={'center':'LOR '}>,
#         <AxesSubplot:title={'center':'CGPA'}>],
#        [<AxesSubplot:title={'center':'Research'}>,
#         <AxesSubplot:title={'center':'Chance of Admit'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#pair plot

sns.pairplot(admission_df)

# %%
# correlation

corr_matrix = admission_df.corr()
plt.figure(figsize =(12,12))
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %% [markdown]
# # 5: CREATE TRAINING AND TESTING DATASET

# %%
admission_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
x = admission_df.drop(columns = ['Chance of Admit'])

# %%
y = admission_df['Chance of Admit']

# %%
x.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500,)

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
# converting it to numpy array

x = np.array(x)
y = np.array(y)

# %%
#optional (reshaping )

y = y.reshape(-1,1)

y.shape
# Out:
# (500, 1)

# %% [markdown]
# # 6: TRAIN AND EVALUATE A LINEAR REGRESSION MODEL

# %%
# scaling the data before training the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler_x = StandardScaler()
x = scaler_x.fit_transform(x)

# %%
scaler_y = StandardScaler()
y = scaler_x.fit_transform(y)

# %%
# spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
LinearRegression_model = LinearRegression()
LinearRegression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy_LinearRegression = LinearRegression_model.score(x_test, y_test)
accuracy_LinearRegression
# Out:
# 0.8019592881158397

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 7))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                400
#
#  activation (Activation)     (None, 50)                0
#
#  dense_1 (Dense)             (None, 150)               7650
#
#  activation_1 (Activation)   (None, 150)               0
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  activation_2 (Activation)   (None, 150)               0
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_3 (Dense)             (None, 50)                7550
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38,301
# Trainable params: 38,301
# Non-trainable params: 0
# _________________________________________________________________
# 2023-08-07 14:54:43.108556: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = ANN_model.fit(x_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 17ms/step - loss: 0.5217 - val_loss: 0.2942
# Epoch 2/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3527 - val_loss: 0.3248
# Epoch 3/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.2891
# Epoch 4/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2720 - val_loss: 0.2572
# Epoch 5/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2561 - val_loss: 0.2654
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2483 - val_loss: 0.2462
# Epoch 7/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2624 - val_loss: 0.2723
# Epoch 8/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2176 - val_loss: 0.2610
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2422 - val_loss: 0.2838
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2304 - val_loss: 0.2586
# Epoch 11/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1958 - val_loss: 0.2563
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2205 - val_loss: 0.2614
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2254 - val_loss: 0.2454
# Epoch 14/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2300 - val_loss: 0.2577
# Epoch 15/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2007 - val_loss: 0.2808
# Epoch 16/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2201 - val_loss: 0.2570
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2286 - val_loss: 0.3027
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2105 - val_loss: 0.2621
# Epoch 19/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2119 - val_loss: 0.2799
# Epoch 20/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2004 - val_loss: 0.2716
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2132 - val_loss: 0.2708
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2006 - val_loss: 0.2698
# Epoch 23/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2036 - val_loss: 0.2717
# Epoch 24/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2111 - val_loss: 0.2661
# Epoch 25/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1912 - val_loss: 0.2584
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2010 - val_loss: 0.2762
# Epoch 27/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2176 - val_loss: 0.2596
# Epoch 28/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2218 - val_loss: 0.3336
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2047 - val_loss: 0.2595
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1785 - val_loss: 0.2679
# Epoch 31/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1903 - val_loss: 0.2693
# Epoch 32/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1877 - val_loss: 0.2906
# Epoch 33/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1797 - val_loss: 0.2633
# Epoch 34/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1781 - val_loss: 0.2548
# Epoch 35/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1860 - val_loss: 0.2794
# Epoch 36/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1880 - val_loss: 0.2634
# Epoch 37/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1902 - val_loss: 0.2784
# Epoch 38/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1728 - val_loss: 0.2573
# Epoch 39/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1755 - val_loss: 0.2580
# Epoch 40/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2119 - val_loss: 0.2799
# Epoch 41/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1875 - val_loss: 0.2781
# Epoch 42/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1695 - val_loss: 0.2858
# Epoch 43/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1797 - val_loss: 0.2692
# Epoch 44/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1843 - val_loss: 0.2611
# Epoch 45/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1686 - val_loss: 0.2798
# Epoch 46/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1732 - val_loss: 0.2580
# Epoch 47/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1650 - val_loss: 0.2976
# Epoch 48/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1685 - val_loss: 0.2692
# Epoch 49/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1693 - val_loss: 0.2706
# Epoch 50/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1619 - val_loss: 0.2973
# Epoch 51/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1895 - val_loss: 0.2734
# Epoch 52/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1676 - val_loss: 0.2990
# Epoch 53/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1599 - val_loss: 0.2543
# Epoch 54/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1589 - val_loss: 0.2762
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1483 - val_loss: 0.2743
# Epoch 56/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1542 - val_loss: 0.2696
# Epoch 57/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1576 - val_loss: 0.2704
# Epoch 58/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1740 - val_loss: 0.3157
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1619 - val_loss: 0.2770
# Epoch 60/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1582 - val_loss: 0.2735
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1566 - val_loss: 0.2931
# Epoch 62/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1598 - val_loss: 0.2854
# Epoch 63/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1579 - val_loss: 0.2691
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1313 - val_loss: 0.2652
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1455 - val_loss: 0.2765
# Epoch 66/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1493 - val_loss: 0.2668
# Epoch 67/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1187 - val_loss: 0.2736
# Epoch 68/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1539 - val_loss: 0.2784
# Epoch 69/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1365 - val_loss: 0.2705
# Epoch 70/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1437 - val_loss: 0.2697
# Epoch 71/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1387 - val_loss: 0.2800
# Epoch 72/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1557 - val_loss: 0.2741
# Epoch 73/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1465 - val_loss: 0.2968
# Epoch 74/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1428 - val_loss: 0.2779
# Epoch 75/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1407 - val_loss: 0.2726
# Epoch 76/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1450 - val_loss: 0.2852
# Epoch 77/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1587 - val_loss: 0.2706
# Epoch 78/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1373 - val_loss: 0.2809
# Epoch 79/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1332 - val_loss: 0.2709
# Epoch 80/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1352 - val_loss: 0.2745
# Epoch 81/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1267 - val_loss: 0.2861
# Epoch 82/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1314 - val_loss: 0.2802
# Epoch 83/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1354 - val_loss: 0.2759
# Epoch 84/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1332 - val_loss: 0.2927
# Epoch 85/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1555 - val_loss: 0.2794
# Epoch 86/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1242 - val_loss: 0.2923
# Epoch 87/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1250 - val_loss: 0.2833
# Epoch 88/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1288 - val_loss: 0.2655
# Epoch 89/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1201 - val_loss: 0.2873
# Epoch 90/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1196 - val_loss: 0.2716
# Epoch 91/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1182 - val_loss: 0.2688
# Epoch 92/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1228 - val_loss: 0.2830
# Epoch 93/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1215 - val_loss: 0.2966
# Epoch 94/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1226 - val_loss: 0.2838
# Epoch 95/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1447 - val_loss: 0.2727
# Epoch 96/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1095 - val_loss: 0.2834
# Epoch 97/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1288 - val_loss: 0.2825
# Epoch 98/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1083 - val_loss: 0.2933
# Epoch 99/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1161 - val_loss: 0.2861
# Epoch 100/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1328 - val_loss: 0.2975

# %%
result = ANN_model.evaluate(x_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1731
# Accuracy : 0.8269140869379044

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %% [markdown]
# # 8: TRAIN AND EVALUATE A DECISION TREE AND RANDOM FOREST MODELS

# %%
# Decision tree builds regression or classification models in the form of a tree structure. 
# Decision tree breaks down a dataset into smaller subsets while at the same time an associated decision tree is incrementally developed. 
# The final result is a tree with decision nodes and leaf nodes.
# Great resource: https://www.saedsayad.com/decision_tree_reg.htm

from sklearn.tree import DecisionTreeRegressor
DecisionTree_model = DecisionTreeRegressor()
DecisionTree_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
accuracy_DecisionTree = DecisionTree_model.score(x_test, y_test)
accuracy_DecisionTree
# Out:
# 0.5530150753768847

# %%
# Many decision Trees make up a random forest model which is an ensemble model. 
# Predictions made by each decision tree are averaged to get the prediction of random forest model.
# A random forest regressor fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. 



from sklearn.ensemble import RandomForestRegressor
RandomForest_model = RandomForestRegressor(n_estimators=100, max_depth =10)
RandomForest_model.fit(x_train, y_train)
# Out:
# /var/folders/dz/mldm4fbd58qbpmypqtnlp39c0000gn/T/ipykernel_7869/3928662833.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RandomForest_model.fit(x_train, y_train)
# RandomForestRegressor(max_depth=10)

# %%
accuracy_RandomForest = RandomForest_model.score(x_test, y_test)
accuracy_RandomForest
# Out:
# 0.7883113754033549

# %% [markdown]
# # 10: CALCULATE REGRESSION MODEL KPIs

# %%
y_predict = LinearRegression_model.predict(x_test)
plt.plot(y_test, y_predict, '^', color = 'r')

# %%
scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = x_test.shape[1]
n = len(x_test)
n
# Out:
# 75

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.42
# MSE = 0.17620644095273524
# MAE = 0.2958922126423766
# R2 = 0.8019592881158397
# Adjusted R2 = 0.781268467471226
